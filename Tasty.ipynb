# %%
# !pip install tastytrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 2.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: toolz
#     Found existing installation: toolz 0.12.1
#     Uninstalling toolz-0.12.1:
#       Successfully uninstalled toolz-0.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibis-framework 9.5.0 requires toolz<1,>=0.11, but you have toolz 1.1.0 which is incompatible.
# ...

# %%
from tastytrade import Session, Account

CLIENT_SECRET = '72c3b57bbc344a14d84ecfb23476b5daf16ab36d'
REFRESH_TOKEN = 'eyJhbGciOiJFZERTQSIsInR5cCI6InJ0K2p3dCIsImtpZCI6IjlWdkQwX3IwZFBZM09EVUdpX2VVSkh0WFZYckVUY2ZzTVQyVmVOcWxoR0UiLCJqa3UiOiJodHRwczovL2ludGVyaW9yLWFwaS5jaDIudGFzdHl3b3Jrcy5jb20vb2F1dGgvandrcyJ9..rik8DNXPL-bVZprbOGQ5wdWDotX2oC4W6aDxlYJz1Rp8swPJ-68Cy4gKLWJOe-3ZYzq-3Y0o-HunFlrBr2EEDQ'



session = Session(CLIENT_SECRET, REFRESH_TOKEN)
print("Auth OK if no error above.")

accounts = Account.get(session)
account = accounts[0]


positions = account.get_positions(session)

print(f"Total Positions: {len(positions)}\n")

for position in positions:
    print(f"Symbol: {position.symbol}")
    print(f"  Type: {position.instrument_type}")
    print(f"  Quantity: {position.quantity}")
    print(f"  Direction: {position.quantity_direction}")  # Long or Short
    print(f"  Average Cost: ${position.average_open_price}")
    print(f"  Current Price: ${position.close_price}")
    print(f"  Multiplier: {position.multiplier}")
    #print(f"  Unrealized P&L: ${position.unrealized_day_gain}")
    #print(f"  Realized P&L: ${position.realized_day_gain}")
    print()
# Out:
# DEBUG:tastytrade:Refreshed token, expires in 900ms
# Auth OK if no error above.
# Total Positions: 10
#
# Symbol: ORCL
#   Type: InstrumentType.EQUITY
#   Quantity: 200
#   Direction: Long
#   Average Cost: $320.0
#   Current Price: $197.49
#   Multiplier: 1
#
# Symbol: NVTS  260618C00006000
#   Type: InstrumentType.EQUITY_OPTION
#   Quantity: 2
#   Direction: Long
#   Average Cost: $8.3
#   Current Price: $2.69
#   Multiplier: 100
#
# Symbol: POET
#   Type: InstrumentType.EQUITY
#   Quantity: 200
#   Direction: Long
#   Average Cost: $6.4797
#   Current Price: $7.02
#   Multiplier: 1
#
# Symbol: SOFI  260618C00017000
#   Type: InstrumentType.EQUITY_OPTION
#   Quantity: 1
#   Direction: Long
#   Average Cost: $14.35
#   Current Price: $11.54
#   Multiplier: 100
#
# Symbol: SNDX
#   Type: InstrumentType.EQUITY
#   Quantity: 100
#   Direction: Long
#   Average Cost: $14.28
#   Current Price: $21.6
#   Multiplier: 1
#
# Symbol: ASST
#   Type: InstrumentType.EQUITY
#   Quantity: 300
# ...
